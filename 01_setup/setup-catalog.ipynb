# %% [markdown]
# # Setup Catalog and Schemas
# ## Healthcare Lakehouse Project
#
# This notebook creates the Unity Catalog and schema structure for the healthcare lakehouse architecture.
# It establishes the three-layer medallion architecture: **Bronze**, **Silver**, and **Gold**.

# %% [markdown]
# ### Step 1: Create Catalog
# Creates the main catalog `healthcare_lakehouse` if it doesn't exist and sets it as the active catalog.

# %%
# Databricks notebook source
# MAGIC %sql
# MAGIC CREATE CATALOG IF NOT EXISTS healthcare_lakehouse;
# MAGIC USE CATALOG healthcare_lakehouse

# %% [markdown]
# ### Step 2: Create Medallion Architecture Schemas
# Creates three schemas representing the medallion architecture layers:
# - **Bronze**: Raw data ingestion layer
# - **Silver**: Cleaned and transformed data layer
# - **Gold**: Aggregated business-level metrics layer

# %%
# Databricks notebook source
# MAGIC %sql
# MAGIC create schema if not exists healthcare_lakehouse.gold;
# MAGIC create schema if not exists healthcare_lakehouse.silver;
# MAGIC create schema if not exists healthcare_lakehouse.bronze;
